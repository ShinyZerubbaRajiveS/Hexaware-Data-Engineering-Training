-- %%
CREATE OR REPLACE TABLE ecommerce_orders ( order_id INT, customer_name STRING, city STRING, product STRING, quantity INT, price INT, order_status STRING ) USING DELTA;

-- %%
%sql INSERT INTO ecommerce_orders VALUES (101,'Amit Sharma','Hyderabad','Laptop',1,75000,'Placed'), (102,'Priya Reddy','Bangalore','Mobile',2,30000,'Placed'), (103,'Rohit Mehta','Mumbai','Headphones',3,2000,'Shipped'), (104,'Sneha Iyer','Chennai','Laptop',1,72000,'Placed'), (105,'Karan Patel','Ahmedabad','Tablet',2,25000,'Cancelled'), (106,'Ananya Das','Kolkata','Mobile',1,28000,'Placed'), (107,'Vikram Singh','Delhi','Camera',1,55000,'Placed'), (108,'Meera Nair','Bangalore','Laptop',1,80000,'Placed');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

-- %% [markdown]
-- ##**PART 1 — INSERT Exercises**

-- %%
-- 1. Insert Rahul Verma (Mumbai, Tablet, 27000)
INSERT INTO ecommerce_orders VALUES
(109, 'Rahul Verma', 'Mumbai', 'Tablet', 1, 27000, 'Placed');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
-- 2. Insert two new orders (Arjun Nair & Kavya Reddy)

INSERT INTO ecommerce_orders VALUES
(110, 'Arjun Nair', 'Kochi', 'Mobile', 1, 30000, 'Placed'),
(111, 'Kavya Reddy', 'Hyderabad', 'Laptop', 1, 75000, 'Placed');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

-- %%
-- 3. Insert an order with status = 'Shipped'

INSERT INTO ecommerce_orders VALUES
(112, 'Ramesh Gupta', 'Delhi', 'Camera', 1, 50000, 'Shipped')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
-- 4. Insert an order with quantity = 5 headphones

INSERT INTO ecommerce_orders VALUES
(113, 'Suresh Kumar', 'Chennai', 'Headphones', 5, 2000, 'Placed');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
-- 5. Insert 3 new orders for Hyderabad customers

INSERT INTO ecommerce_orders VALUES
(114, 'Pooja Sharma', 'Hyderabad', 'Mobile', 1, 25000, 'Placed'),
(115, 'Ravi Teja', 'Hyderabad', 'Tablet', 2, 26000, 'Placed'),
(116, 'Neha Kapoor', 'Hyderabad', 'Laptop', 1, 78000, 'Placed');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ##PART 2 — UPDATE Exercises

-- %%
-- 1. Change order_status of order 101 to Shipped
UPDATE ecommerce_orders
SET order_status = 'Shipped'
WHERE order_id = 101;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
-- 2. Increase quantity of order 102 by 1

UPDATE ecommerce_orders
SET quantity = quantity + 1
WHERE order_id = 102;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
-- 3. Change price of all Laptop orders to 78000
UPDATE ecommerce_orders
SET price = 78000
WHERE product = 'Laptop';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>5</td></tr></tbody></table></div>

-- %%
-- 4. Update city of Amit Sharma to Secunderabad
UPDATE ecommerce_orders
SET city = 'Secunderabad'
WHERE customer_name = 'Amit Sharma';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
-- 5. Change order_status to Delivered where product = Mobile

UPDATE ecommerce_orders
SET order_status = 'Delivered'
WHERE product = 'Mobile';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>4</td></tr></tbody></table></div>

-- %%
-- 6. Update price of Headphones to 2500

UPDATE ecommerce_orders
SET price = 2500
WHERE product = 'Headphones';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

-- %%
-- 7. Increase price of all Tablet products by 1000

UPDATE ecommerce_orders
SET price = price + 1000
WHERE product = 'Tablet';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

-- %%
-- 8. Change order_status of Bangalore orders to Processing

UPDATE ecommerce_orders
SET order_status = 'Processing'
WHERE city = 'Bangalore';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

-- %%
-- 9. Update quantity to 2 where quantity = 1

UPDATE ecommerce_orders
SET quantity = 2
WHERE quantity = 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>11</td></tr></tbody></table></div>

-- %%
-- 10. Change city Ahmedabad to Surat

UPDATE ecommerce_orders
SET city = 'Surat'
WHERE city = 'Ahmedabad';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- ##PART 3 — DELETE Exercises

-- %%
-- 1. Delete orders where order_status = Cancelled

DELETE FROM ecommerce_orders
WHERE order_status = 'Cancelled';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
-- 2. Delete orders where quantity > 3

DELETE FROM ecommerce_orders
WHERE quantity > 3;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
-- 3. Delete orders where product = Camera

DELETE FROM ecommerce_orders
WHERE product = 'Camera';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

-- %%
--4. Delete orders placed from Kolkata

DELETE FROM ecommerce_orders
WHERE city = 'Kolkata';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
-- 5. Delete orders where price < 5000

DELETE FROM ecommerce_orders
WHERE price < 5000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
--6. Delete orders where customer_name starts with A

DELETE FROM ecommerce_orders
WHERE customer_name LIKE 'A%';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

-- %%
-- 7. Delete all Tablet orders

DELETE FROM ecommerce_orders
WHERE product = 'Tablet';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

-- %%
-- 8. Delete orders where city = Mumbai AND quantity = 1

DELETE FROM ecommerce_orders
WHERE city = 'Mumbai'
AND quantity = 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %%
-- 9. Delete orders with price greater than 80000

DELETE FROM ecommerce_orders
WHERE price > 80000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %%
-- 10. Delete last inserted order
DELETE FROM ecommerce_orders
WHERE order_id = (SELECT MAX(order_id) FROM ecommerce_orders);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- ##PART 4 — MERGE / UPSERT Exercises

-- %%
%sql
CREATE OR REPLACE TEMP VIEW incoming_orders AS
SELECT * FROM VALUES
(102,'Priya Reddy','Bangalore','Mobile',4,30000,'Delivered'),
(104,'Sneha Iyer','Chennai','Laptop',1,72000,'Shipped'),
(109,'Rahul Verma','Mumbai','Tablet',2,26000,'Placed'),
(110,'Divya Menon','Kochi','Mobile',1,27000,'Placed'),
(111,'Farhan Ali','Hyderabad','Laptop',1,79000,'Placed')
AS incoming_orders(order_id,customer_name,city,product,quantity,price,order_status);

-- %%
-- 1. Merge incoming_orders into ecommerce_orders

MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id

WHEN MATCHED THEN
UPDATE SET
  target.customer_name = source.customer_name,
  target.city = source.city,
  target.product = source.product,
  target.quantity = source.quantity,
  target.price = source.price,
  target.order_status = source.order_status

WHEN NOT MATCHED THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 2. Update matching orders using WHEN MATCHED

MERGE INTO ecommerce_orders t
USING incoming_orders s
ON t.order_id = s.order_id

WHEN MATCHED THEN
UPDATE SET
  t.order_status = s.order_status
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 3. Insert new orders using WHEN NOT MATCHED

MERGE INTO ecommerce_orders t
USING incoming_orders s
ON t.order_id = s.order_id

WHEN NOT MATCHED THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
--4. After merge, list orders sorted by order_id

SELECT *
FROM ecommerce_orders
ORDER BY order_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>102</td><td>Priya Reddy</td><td>Bangalore</td><td>Mobile</td><td>4</td><td>30000</td><td>Delivered</td></tr><tr><td>104</td><td>Sneha Iyer</td><td>Chennai</td><td>Laptop</td><td>1</td><td>72000</td><td>Shipped</td></tr><tr><td>108</td><td>Meera Nair</td><td>Bangalore</td><td>Laptop</td><td>2</td><td>78000</td><td>Processing</td></tr><tr><td>109</td><td>Rahul Verma</td><td>Mumbai</td><td>Tablet</td><td>2</td><td>26000</td><td>Placed</td></tr><tr><td>110</td><td>Divya Menon</td><td>Kochi</td><td>Mobile</td><td>1</td><td>27000</td><td>Placed</td></tr><tr><td>111</td><td>Farhan Ali</td><td>Hyderabad</td><td>Laptop</td><td>1</td><td>79000</td><td>Placed</td></tr><tr><td>114</td><td>Pooja Sharma</td><td>Hyderabad</td><td>Mobile</td><td>2</td><td>25000</td><td>Delivered</td></tr></tbody></table></div>

-- %%
-- 5. Identify which rows were inserted vs updated

SELECT 
  s.order_id,
  CASE 
    WHEN t.order_id IS NULL THEN 'INSERTED'
    ELSE 'UPDATED'
  END AS action
FROM incoming_orders s
LEFT JOIN ecommerce_orders t
ON s.order_id = t.order_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>action</th></tr></thead><tbody><tr><td>102</td><td>UPDATED</td></tr><tr><td>104</td><td>UPDATED</td></tr><tr><td>109</td><td>UPDATED</td></tr><tr><td>110</td><td>UPDATED</td></tr><tr><td>111</td><td>UPDATED</td></tr></tbody></table></div>

-- %%
-- 6. Modify merge → update ONLY order_status
MERGE INTO ecommerce_orders t
USING incoming_orders s
ON t.order_id = s.order_id

WHEN MATCHED THEN
UPDATE SET
  t.order_status = s.order_status

WHEN NOT MATCHED THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 7. Update quantity ONLY when it increases
MERGE INTO ecommerce_orders t
USING incoming_orders s
ON t.order_id = s.order_id

WHEN MATCHED AND s.quantity > t.quantity THEN
UPDATE SET
  t.quantity = s.quantity

WHEN NOT MATCHED THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 8. Ignore cancelled orders
MERGE INTO ecommerce_orders t
USING incoming_orders s
ON t.order_id = s.order_id

WHEN MATCHED AND s.order_status != 'Cancelled' THEN
UPDATE SET
  t.customer_name = s.customer_name,
  t.order_status = s.order_status

WHEN NOT MATCHED AND s.order_status != 'Cancelled' THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 9. Insert ONLY Laptop products
MERGE INTO ecommerce_orders t
USING incoming_orders s
ON t.order_id = s.order_id

WHEN MATCHED THEN
UPDATE SET
  t.order_status = s.order_status

WHEN NOT MATCHED AND s.product = 'Laptop' THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 10. Update price ONLY if new price is higher
MERGE INTO ecommerce_orders t
USING incoming_orders s
ON t.order_id = s.order_id

WHEN MATCHED AND s.price > t.price THEN
UPDATE SET
  t.price = s.price

WHEN NOT MATCHED THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %% [markdown]
-- ##PART 5 — Realistic UPSERT Scenario

-- %%
CREATE OR REPLACE TEMP VIEW daily_updates AS SELECT * FROM VALUES (103,'Rohit Mehta','Mumbai','Headphones',5,2200,'Delivered'), (106,'Ananya Das','Kolkata','Mobile',2,28000,'Shipped'), (112,'Sanjay Gupta','Delhi','Tablet',1,24000,'Placed') AS daily_updates(order_id,customer_name,city,product,quantity,price,order_status);

-- %%
-- 1. Merge daily_updates into ecommerce_orders

MERGE INTO ecommerce_orders t
USING daily_updates s
ON t.order_id = s.order_id

WHEN MATCHED THEN
UPDATE SET
  t.quantity = s.quantity

WHEN NOT MATCHED THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>0</td><td>0</td><td>3</td></tr></tbody></table></div>

-- %%
-- 2. Update quantity for existing orders

MERGE INTO ecommerce_orders t
USING daily_updates s
ON t.order_id = s.order_id

WHEN MATCHED THEN
UPDATE SET
  t.quantity = s.quantity
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 3. Insert orders that do not exist

MERGE INTO ecommerce_orders t
USING daily_updates s
ON t.order_id = s.order_id

WHEN NOT MATCHED THEN
INSERT *
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
-- 4. Count how many rows were UPDATED


SELECT COUNT(*) AS updated_count
FROM daily_updates s
INNER JOIN ecommerce_orders t
ON s.order_id = t.order_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>updated_count</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

-- %%
-- 5. Count how many rows were INSERTED


SELECT COUNT(*) AS inserted_count
FROM daily_updates s
LEFT JOIN ecommerce_orders t
ON s.order_id = t.order_id
WHERE t.order_id IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>inserted_count</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %%
-- 6. Show final table sorted by price DESC
SELECT *
FROM ecommerce_orders
ORDER BY price DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>111</td><td>Farhan Ali</td><td>Hyderabad</td><td>Laptop</td><td>1</td><td>79000</td><td>Placed</td></tr><tr><td>108</td><td>Meera Nair</td><td>Bangalore</td><td>Laptop</td><td>2</td><td>78000</td><td>Processing</td></tr><tr><td>104</td><td>Sneha Iyer</td><td>Chennai</td><td>Laptop</td><td>1</td><td>72000</td><td>Shipped</td></tr><tr><td>102</td><td>Priya Reddy</td><td>Bangalore</td><td>Mobile</td><td>4</td><td>30000</td><td>Delivered</td></tr><tr><td>106</td><td>Ananya Das</td><td>Kolkata</td><td>Mobile</td><td>2</td><td>28000</td><td>Shipped</td></tr><tr><td>110</td><td>Divya Menon</td><td>Kochi</td><td>Mobile</td><td>1</td><td>27000</td><td>Placed</td></tr><tr><td>109</td><td>Rahul Verma</td><td>Mumbai</td><td>Tablet</td><td>2</td><td>26000</td><td>Placed</td></tr><tr><td>114</td><td>Pooja Sharma</td><td>Hyderabad</td><td>Mobile</td><td>2</td><td>25000</td><td>Delivered</td></tr><tr><td>112</td><td>Sanjay Gupta</td><td>Delhi</td><td>Tablet</td><td>1</td><td>24000</td><td>Placed</td></tr><tr><td>103</td><td>Rohit Mehta</td><td>Mumbai</td><td>Headphones</td><td>5</td><td>2200</td><td>Delivered</td></tr></tbody></table></div>
